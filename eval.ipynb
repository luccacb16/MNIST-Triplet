# %%
import warnings; warnings.filterwarnings("ignore", message="Initializing zero-element tensors is a no-op")
import pandas as pd
import torch
import os 
from utils.eval_utils import get_pairs, eval_epochs, MNISTSingleDataset

from utils.utils import aug_transform, simple_transform
from models.omoindrot import Omoindrot

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

IMAGES_PATH = './data/'
EPOCHS_PATH = './checkpoints/'

# %%
test_df = pd.read_csv(os.path.join(IMAGES_PATH, 'mnist_test.csv'))
print(f'Test data shape: {test_df.shape}')

pairs = get_pairs(test_df, 1024)
print(f'Pairs shape: {pairs.shape}')
# Out:
# Test data shape: (10000, 785)
# Pairs shape: (1024, 3)

# %% [markdown]
# # **VAL, FAR, ROC, Dists**

# %%
eval_epochs(epochs_path=EPOCHS_PATH, 
            pairs=pairs,
            model_class=Omoindrot, 
            batch_size=32,
            transform=simple_transform, 
            device=device,
            target_far=1e-3)
# Out:
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 56.15it/s]
# Target FAR: 1e-03 | Threshold: 0.7463
# [epoch_1.pt] Accuracy: 0.8555
# [epoch_1.pt] VAL: 0.7109 | FAR: 0.0000
#
# [epoch_1.pt] Positive mean: 0.6558 ± 0.2306
# [epoch_1.pt] Negative mean: 1.4582 ± 0.1629
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 99.13it/s]
# Target FAR: 1e-03 | Threshold: 0.8702
# [epoch_2.pt] Accuracy: 0.9414
# [epoch_2.pt] VAL: 0.8828 | FAR: 0.0000
#
# [epoch_2.pt] Positive mean: 0.5875 ± 0.2318
# [epoch_2.pt] Negative mean: 1.4514 ± 0.1528
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 103.13it/s]
# Target FAR: 1e-03 | Threshold: 0.8741
# [epoch_3.pt] Accuracy: 0.9502
# [epoch_3.pt] VAL: 0.9004 | FAR: 0.0000
#
# [epoch_3.pt] Positive mean: 0.5548 ± 0.2310
# [epoch_3.pt] Negative mean: 1.4603 ± 0.1406
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 69.22it/s]
# Target FAR: 1e-03 | Threshold: 0.7605
# [epoch_4.pt] Accuracy: 0.9219
# [epoch_4.pt] VAL: 0.8438 | FAR: 0.0000
#
# [epoch_4.pt] Positive mean: 0.5363 ± 0.2299
# [epoch_4.pt] Negative mean: 1.4639 ± 0.1374
# Calculating distances: 100%|██████████| 32/32 [00:03<00:00,  9.17it/s]
# Target FAR: 1e-03 | Threshold: 0.8644
# [epoch_5.pt] Accuracy: 0.9570
# [epoch_5.pt] VAL: 0.9141 | FAR: 0.0000
#
# [epoch_5.pt] Positive mean: 0.5113 ± 0.2299
# [epoch_5.pt] Negative mean: 1.4654 ± 0.1322
# Calculating distances: 100%|██████████| 32/32 [00:06<00:00,  5.28it/s]
# Target FAR: 1e-03 | Threshold: 0.9385
# [epoch_6.pt] Accuracy: 0.9717
# [epoch_6.pt] VAL: 0.9434 | FAR: 0.0000
#
# [epoch_6.pt] Positive mean: 0.4942 ± 0.2334
# [epoch_6.pt] Negative mean: 1.4659 ± 0.1300
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 86.05it/s]
# Target FAR: 1e-03 | Threshold: 0.7661
# [epoch_7.pt] Accuracy: 0.9443
# [epoch_7.pt] VAL: 0.8887 | FAR: 0.0000
#
# [epoch_7.pt] Positive mean: 0.4935 ± 0.2319
# [epoch_7.pt] Negative mean: 1.4631 ± 0.1283
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 100.78it/s]
# Target FAR: 1e-03 | Threshold: 0.8224
# [epoch_8.pt] Accuracy: 0.9541
# [epoch_8.pt] VAL: 0.9082 | FAR: 0.0000
#
# [epoch_8.pt] Positive mean: 0.4765 ± 0.2338
# [epoch_8.pt] Negative mean: 1.4613 ± 0.1331
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 76.29it/s]
# Target FAR: 1e-03 | Threshold: 0.8655
# [epoch_9.pt] Accuracy: 0.9668
# [epoch_9.pt] VAL: 0.9336 | FAR: 0.0000
#
# [epoch_9.pt] Positive mean: 0.4722 ± 0.2312
# [epoch_9.pt] Negative mean: 1.4580 ± 0.1324
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 97.95it/s]
# Target FAR: 1e-03 | Threshold: 0.8251
# [epoch_10.pt] Accuracy: 0.9619
# [epoch_10.pt] VAL: 0.9238 | FAR: 0.0000
#
# [epoch_10.pt] Positive mean: 0.4660 ± 0.2332
# [epoch_10.pt] Negative mean: 1.4626 ± 0.1293
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 99.06it/s]
# Target FAR: 1e-03 | Threshold: 0.7972
# [epoch_11.pt] Accuracy: 0.9561
# [epoch_11.pt] VAL: 0.9121 | FAR: 0.0000
#
# [epoch_11.pt] Positive mean: 0.4578 ± 0.2305
# [epoch_11.pt] Negative mean: 1.4585 ± 0.1310
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 95.68it/s]
# Target FAR: 1e-03 | Threshold: 0.8068
# [epoch_12.pt] Accuracy: 0.9541
# [epoch_12.pt] VAL: 0.9082 | FAR: 0.0000
#
# [epoch_12.pt] Positive mean: 0.4516 ± 0.2309
# [epoch_12.pt] Negative mean: 1.4607 ± 0.1280
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 80.21it/s]
# Target FAR: 1e-03 | Threshold: 0.8021
# [epoch_13.pt] Accuracy: 0.9570
# [epoch_13.pt] VAL: 0.9141 | FAR: 0.0000
#
# [epoch_13.pt] Positive mean: 0.4452 ± 0.2273
# [epoch_13.pt] Negative mean: 1.4623 ± 0.1271
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 82.55it/s]
# Target FAR: 1e-03 | Threshold: 0.7503
# [epoch_14.pt] Accuracy: 0.9531
# [epoch_14.pt] VAL: 0.9062 | FAR: 0.0000
#
# [epoch_14.pt] Positive mean: 0.4470 ± 0.2272
# [epoch_14.pt] Negative mean: 1.4674 ± 0.1273
# Calculating distances: 100%|██████████| 32/32 [00:01<00:00, 26.54it/s]
# Target FAR: 1e-03 | Threshold: 0.7881
# [epoch_15.pt] Accuracy: 0.9570
# [epoch_15.pt] VAL: 0.9141 | FAR: 0.0000
#
# [epoch_15.pt] Positive mean: 0.4406 ± 0.2257
# [epoch_15.pt] Negative mean: 1.4610 ± 0.1295
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 66.16it/s]
# Target FAR: 1e-03 | Threshold: 0.8192
# [epoch_16.pt] Accuracy: 0.9658
# [epoch_16.pt] VAL: 0.9316 | FAR: 0.0000
#
# [epoch_16.pt] Positive mean: 0.4364 ± 0.2275
# [epoch_16.pt] Negative mean: 1.4595 ± 0.1314
# Calculating distances: 100%|██████████| 32/32 [00:02<00:00, 13.67it/s]
# Target FAR: 1e-03 | Threshold: 0.8091
# [epoch_17.pt] Accuracy: 0.9609
# [epoch_17.pt] VAL: 0.9219 | FAR: 0.0000
#
# [epoch_17.pt] Positive mean: 0.4307 ± 0.2310
# [epoch_17.pt] Negative mean: 1.4607 ± 0.1281
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 106.76it/s]
# Target FAR: 1e-03 | Threshold: 0.8454
# [epoch_18.pt] Accuracy: 0.9678
# [epoch_18.pt] VAL: 0.9355 | FAR: 0.0000
#
# [epoch_18.pt] Positive mean: 0.4322 ± 0.2269
# [epoch_18.pt] Negative mean: 1.4621 ± 0.1242
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 85.95it/s]
# Target FAR: 1e-03 | Threshold: 0.7806
# [epoch_19.pt] Accuracy: 0.9600
# [epoch_19.pt] VAL: 0.9199 | FAR: 0.0000
#
# [epoch_19.pt] Positive mean: 0.4320 ± 0.2266
# [epoch_19.pt] Negative mean: 1.4656 ± 0.1237
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 90.13it/s]
# Target FAR: 1e-03 | Threshold: 0.8916
# [epoch_20.pt] Accuracy: 0.9717
# [epoch_20.pt] VAL: 0.9434 | FAR: 0.0000
#
# [epoch_20.pt] Positive mean: 0.4232 ± 0.2290
# [epoch_20.pt] Negative mean: 1.4625 ± 0.1223

# %% [markdown]
# # **Visualizar os embeddings**

# %%
import os
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %%
def view_embs(epochs_path, model_class, test_df, transform, device):
    models_name = os.listdir(epochs_path)
    models_name = [model for model in models_name if 'bons' not in model]
    models_name_sorted = sorted(models_name, key=lambda x: int(x.replace('.pt', '').split('_')[1]))

    modelo = model_class(emb_size=64).to(device)
    modelo.eval()

    test_dataset = MNISTSingleDataset(test_df, transform=transform)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, pin_memory=True, num_workers=0)

    model_path = os.path.join(epochs_path, model)
    load = torch.load(model_path)
    load = {k.replace('_orig_mod.', ''): v for k, v in load.items()}
    modelo.load_state_dict(load)
    
    embeddings = []
    with torch.no_grad():
        for (imgs, labels) in test_dataloader:
            images = imgs.to(device)
            embeddings.append(modelo(images).cpu().numpy())
    embeddings = np.concatenate(embeddings)
    
    # Reduzir dimensionalidade com t-SNE
    tsne = TSNE(n_components=2, perplexity=30, max_iter=300)
    embeddings_tsne = tsne.fit_transform(embeddings)
    
    # Reduzir dimensionalidade com PCA
    pca = PCA(n_components=2)
    embeddings_pca = pca.fit_transform(embeddings)
    
    plt.figure(figsize=(24, 8))
    
    # Plotar t-SNE
    plt.subplot(1, 2, 1)
    scatter = plt.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], c=test_df['label'], cmap='tab10', s=5)
    plt.colorbar(scatter)
    plt.title(f't-SNE {model}')
    
    # Plotar PCA
    plt.subplot(1, 2, 2)
    scatter = plt.scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], c=test_df['label'], cmap='tab10', s=5)
    plt.colorbar(scatter)
    plt.title(f'PCA {model}')
    
    plt.show()

view_embs(EPOCHS_PATH, Omoindrot, test_df, simple_transform, device)
