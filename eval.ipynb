# %%
import warnings; warnings.filterwarnings("ignore", message="Initializing zero-element tensors is a no-op")
import pandas as pd
import torch
import os 

from utils.eval_utils import get_pairs, eval_epochs, MNISTSingleDataset
from utils.utils import aug_transform, simple_transform
from models.omoindrot import Omoindrot

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

IMAGES_PATH = './data/'
EPOCHS_PATH = './checkpoints/'

# %%
test_df = pd.read_csv(os.path.join(IMAGES_PATH, 'mnist_test.csv'))
print(f'Test data shape: {test_df.shape}')

pairs = get_pairs(test_df, 1024)
print(f'Pairs shape: {pairs.shape}')
# Out:
# Test data shape: (10000, 785)
# Pairs shape: (1024, 3)

# %% [markdown]
# # **VAL, FAR, ROC, Dists**

# %%
eval_epochs(epochs_path=EPOCHS_PATH, 
            pairs=pairs,
            model_class=Omoindrot, 
            batch_size=32,
            transform=simple_transform, 
            device=device,
            target_far=1e-3)
# Out:
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 69.66it/s]
# Target FAR: 1e-03 | Threshold: 0.9692
# [epoch_1.pt] Accuracy: 0.9385
# [epoch_1.pt] VAL: 0.8770 | FAR: 0.0000
#
# [epoch_1.pt] Positive mean: 0.7424 ± 0.1953
# [epoch_1.pt] Negative mean: 1.4438 ± 0.1547
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 108.79it/s]
# Target FAR: 1e-03 | Threshold: 0.9766
# [epoch_2.pt] Accuracy: 0.9619
# [epoch_2.pt] VAL: 0.9238 | FAR: 0.0000
#
# [epoch_2.pt] Positive mean: 0.6963 ± 0.1902
# [epoch_2.pt] Negative mean: 1.4562 ± 0.1510
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 117.08it/s]
# Target FAR: 1e-03 | Threshold: 0.9998
# [epoch_3.pt] Accuracy: 0.9707
# [epoch_3.pt] VAL: 0.9414 | FAR: 0.0000
#
# [epoch_3.pt] Positive mean: 0.6647 ± 0.1830
# [epoch_3.pt] Negative mean: 1.4573 ± 0.1411
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 102.51it/s]
# Target FAR: 1e-03 | Threshold: 0.9741
# [epoch_4.pt] Accuracy: 0.9717
# [epoch_4.pt] VAL: 0.9434 | FAR: 0.0000
#
# [epoch_4.pt] Positive mean: 0.6527 ± 0.1799
# [epoch_4.pt] Negative mean: 1.4558 ± 0.1429
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 105.71it/s]
# Target FAR: 1e-03 | Threshold: 1.0020
# [epoch_5.pt] Accuracy: 0.9736
# [epoch_5.pt] VAL: 0.9473 | FAR: 0.0000
#
# [epoch_5.pt] Positive mean: 0.6437 ± 0.1844
# [epoch_5.pt] Negative mean: 1.4567 ± 0.1402
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 106.23it/s]
# Target FAR: 1e-03 | Threshold: 1.0097
# [epoch_6.pt] Accuracy: 0.9795
# [epoch_6.pt] VAL: 0.9590 | FAR: 0.0000
#
# [epoch_6.pt] Positive mean: 0.6251 ± 0.1770
# [epoch_6.pt] Negative mean: 1.4513 ± 0.1462
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 104.03it/s]
# Target FAR: 1e-03 | Threshold: 1.0199
# [epoch_7.pt] Accuracy: 0.9814
# [epoch_7.pt] VAL: 0.9629 | FAR: 0.0000
#
# [epoch_7.pt] Positive mean: 0.6267 ± 0.1759
# [epoch_7.pt] Negative mean: 1.4549 ± 0.1421
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 104.20it/s]
# Target FAR: 1e-03 | Threshold: 0.9730
# [epoch_8.pt] Accuracy: 0.9795
# [epoch_8.pt] VAL: 0.9590 | FAR: 0.0000
#
# [epoch_8.pt] Positive mean: 0.6154 ± 0.1815
# [epoch_8.pt] Negative mean: 1.4544 ± 0.1437
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 105.83it/s]
# Target FAR: 1e-03 | Threshold: 1.0025
# [epoch_9.pt] Accuracy: 0.9795
# [epoch_9.pt] VAL: 0.9590 | FAR: 0.0000
#
# [epoch_9.pt] Positive mean: 0.6129 ± 0.1762
# [epoch_9.pt] Negative mean: 1.4513 ± 0.1420
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 104.17it/s]
# Target FAR: 1e-03 | Threshold: 1.0479
# [epoch_10.pt] Accuracy: 0.9854
# [epoch_10.pt] VAL: 0.9707 | FAR: 0.0000
#
# [epoch_10.pt] Positive mean: 0.6117 ± 0.1770
# [epoch_10.pt] Negative mean: 1.4571 ± 0.1366
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 91.73it/s]
# Target FAR: 1e-03 | Threshold: 0.9525
# [epoch_11.pt] Accuracy: 0.9736
# [epoch_11.pt] VAL: 0.9473 | FAR: 0.0000
#
# [epoch_11.pt] Positive mean: 0.6042 ± 0.1707
# [epoch_11.pt] Negative mean: 1.4614 ± 0.1360
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 115.58it/s]
# Target FAR: 1e-03 | Threshold: 0.9062
# [epoch_12.pt] Accuracy: 0.9668
# [epoch_12.pt] VAL: 0.9336 | FAR: 0.0000
#
# [epoch_12.pt] Positive mean: 0.5977 ± 0.1746
# [epoch_12.pt] Negative mean: 1.4519 ± 0.1415
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 102.00it/s]
# Target FAR: 1e-03 | Threshold: 0.9331
# [epoch_13.pt] Accuracy: 0.9746
# [epoch_13.pt] VAL: 0.9492 | FAR: 0.0000
#
# [epoch_13.pt] Positive mean: 0.5863 ± 0.1742
# [epoch_13.pt] Negative mean: 1.4519 ± 0.1436
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 95.63it/s]
# Target FAR: 1e-03 | Threshold: 0.8713
# [epoch_14.pt] Accuracy: 0.9697
# [epoch_14.pt] VAL: 0.9395 | FAR: 0.0000
#
# [epoch_14.pt] Positive mean: 0.5872 ± 0.1746
# [epoch_14.pt] Negative mean: 1.4567 ± 0.1400
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 93.56it/s]
# Target FAR: 1e-03 | Threshold: 0.8684
# [epoch_15.pt] Accuracy: 0.9648
# [epoch_15.pt] VAL: 0.9297 | FAR: 0.0000
#
# [epoch_15.pt] Positive mean: 0.5851 ± 0.1749
# [epoch_15.pt] Negative mean: 1.4423 ± 0.1433
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 103.56it/s]
# Target FAR: 1e-03 | Threshold: 0.8799
# [epoch_16.pt] Accuracy: 0.9629
# [epoch_16.pt] VAL: 0.9258 | FAR: 0.0000
#
# [epoch_16.pt] Positive mean: 0.5948 ± 0.1769
# [epoch_16.pt] Negative mean: 1.4510 ± 0.1352
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 110.81it/s]
# Target FAR: 1e-03 | Threshold: 0.8801
# [epoch_17.pt] Accuracy: 0.9688
# [epoch_17.pt] VAL: 0.9375 | FAR: 0.0000
#
# [epoch_17.pt] Positive mean: 0.5814 ± 0.1719
# [epoch_17.pt] Negative mean: 1.4578 ± 0.1404
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 72.44it/s]
# Target FAR: 1e-03 | Threshold: 0.8798
# [epoch_18.pt] Accuracy: 0.9658
# [epoch_18.pt] VAL: 0.9316 | FAR: 0.0000
#
# [epoch_18.pt] Positive mean: 0.5810 ± 0.1758
# [epoch_18.pt] Negative mean: 1.4649 ± 0.1356
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 98.85it/s]
# Target FAR: 1e-03 | Threshold: 0.9208
# [epoch_19.pt] Accuracy: 0.9736
# [epoch_19.pt] VAL: 0.9473 | FAR: 0.0000
#
# [epoch_19.pt] Positive mean: 0.5774 ± 0.1723
# [epoch_19.pt] Negative mean: 1.4583 ± 0.1446
# Calculating distances: 100%|██████████| 32/32 [00:00<00:00, 90.68it/s]
# Target FAR: 1e-03 | Threshold: 0.9375
# [epoch_20.pt] Accuracy: 0.9756
# [epoch_20.pt] VAL: 0.9512 | FAR: 0.0000
#
# [epoch_20.pt] Positive mean: 0.5780 ± 0.1715
# [epoch_20.pt] Negative mean: 1.4525 ± 0.1395

# %% [markdown]
# # **Visualizar os embeddings**

# %%
import os
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %%
def view_embs(epochs_path, model_class, test_df, transform, device):
    models_name = os.listdir(epochs_path)
    models_name = [model for model in models_name if 'bons' not in model]
    models_name_sorted = sorted(models_name, key=lambda x: int(x.replace('.pt', '').split('_')[1]))
    model = models_name_sorted[-1]
    model = 'epoch_10.pt'

    modelo = model_class(emb_size=64).to(device)
    modelo.eval()

    test_dataset = MNISTSingleDataset(test_df, transform=transform)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, pin_memory=True, num_workers=0)

    model_path = os.path.join(epochs_path, model)
    load = torch.load(model_path)
    load = {k.replace('_orig_mod.', ''): v for k, v in load.items()}
    modelo.load_state_dict(load)
    
    embeddings = []
    with torch.no_grad():
        for (imgs, labels) in test_dataloader:
            images = imgs.to(device)
            embeddings.append(modelo(images).cpu().numpy())
    embeddings = np.concatenate(embeddings)
    
    # Reduzir dimensionalidade com t-SNE
    tsne = TSNE(n_components=2, perplexity=30, max_iter=300)
    embeddings_tsne = tsne.fit_transform(embeddings)
    
    # Reduzir dimensionalidade com PCA
    pca = PCA(n_components=2)
    embeddings_pca = pca.fit_transform(embeddings)
    
    plt.figure(figsize=(24, 8))
    
    # Plotar t-SNE
    plt.subplot(1, 2, 1)
    scatter = plt.scatter(embeddings_tsne[:, 0], embeddings_tsne[:, 1], c=test_df['label'], cmap='tab10', s=5)
    plt.colorbar(scatter)
    plt.title(f't-SNE {model}')
    
    # Plotar PCA
    plt.subplot(1, 2, 2)
    scatter = plt.scatter(embeddings_pca[:, 0], embeddings_pca[:, 1], c=test_df['label'], cmap='tab10', s=5)
    plt.colorbar(scatter)
    plt.title(f'PCA {model}')
    
    plt.show()

view_embs(EPOCHS_PATH, Omoindrot, test_df, simple_transform, device)
